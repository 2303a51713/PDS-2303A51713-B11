# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51713/PDS-2303A51713-B11/blob/main/Lab_7(18sep).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/content/daily_temperature.csv")

print(data.head())

days = data['Day']
temps = data['Temperature']

plt.figure(figsize=(10, 6))
plt.plot(days, temps, marker='o', linestyle='-', color='b', label='Temperature')

plt.xlabel("Day of the Month")
plt.ylabel("Temperature (°C)")
plt.title("Daily Temperature Variation (Weather Dataset)")
plt.legend()
plt.grid(True)

plt.show()

hottest_day = data.loc[data['Temperature'].idxmax()]
coldest_day = data.loc[data['Temperature'].idxmin()]

print(f"Hottest Day: Day {hottest_day['Day']} with {hottest_day['Temperature']}°C")
print(f"Coldest Day: Day {coldest_day['Day']} with {coldest_day['Temperature']}°C")
# Out:
#    Day  Temperature
# 0    1           22
# 1    2           24
# 2    3           23
# 3    4           25
# 4    5           27
# Hottest Day: Day 12 with 34°C
# Coldest Day: Day 1 with 22°C

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/content/sales_data.csv")

print(data.head())

quarters = data['Quarter']
sales = data['Sales']

plt.figure(figsize=(8, 5))
plt.plot(quarters, sales, marker='o', linestyle='-', color='purple', label='Sales')

peak_idx = sales.idxmax()
plt.scatter(quarters[peak_idx], sales[peak_idx], color='red', s=100, zorder=5, label='Peak Sales')

plt.xlabel("Quarter")
plt.ylabel("Sales (in Units / $)")
plt.title("Quarterly Sales Performance")
plt.legend()
plt.grid(True)

plt.show()

peak_quarter = data.loc[peak_idx]
print(f"Peak Sales: {peak_quarter['Sales']} in {peak_quarter['Quarter']}")
# Out:
#   Quarter  Sales
# 0      Q1  12000
# 1      Q2  15000
# 2      Q3  14000
# 3      Q4  20000
# Peak Sales: 20000 in Q4
